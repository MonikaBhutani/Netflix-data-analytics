# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the dataset

# %%
df= pd.read_csv("BigBasket Products.csv")

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
# View first 12 rows
df.head(12)
# Out:
#     index                                            product  \
# 0       1             Garlic Oil - Vegetarian Capsule 500 mg
# 1       2                              Water Bottle - Orange
# 2       3                     Brass Angle Deep - Plain, No.2
# 3       4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4       5                 Creme Soft Soap - For Hands & Body
# 5       6                  Germ - Removal Multipurpose Wipes
# 6       7                                       Multani Mati
# 7       8                  Hand Sanitizer - 70% Alcohol Base
# 8       9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 9      10               Scrub Pad - Anti- Bacterial, Regular
# 10     11                           Wheat Grass Powder - Raw
# 11     12                     Butter Cookies Gold Collection
#
#                   category            sub_category              brand  \
# 0         Beauty & Hygiene               Hair Care  Sri Sri Ayurveda
# ...

# %%
# Step 4: Dataset Description
df.describe(include='all')
# Out:
#               index                       product          category  \
# count   27555.00000                         27554             27555
# unique          NaN                         23540                11
# top             NaN  Turmeric Powder/Arisina Pudi  Beauty & Hygiene
# freq            NaN                            26              7867
# mean    13778.00000                           NaN               NaN
# std      7954.58767                           NaN               NaN
# min         1.00000                           NaN               NaN
# 25%      6889.50000                           NaN               NaN
# 50%     13778.00000                           NaN               NaN
# 75%     20666.50000                           NaN               NaN
# max     27555.00000                           NaN               NaN
#
#        sub_category   brand     sale_price  market_price       type  \
# count         27555   27554   27549.000000  27555.000000      27555
# ...

# %%
# Step 5: DataFrame Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27549 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18919 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
# Step 6: Top and Least Sold Products (assumption: based on rating)
print("\nTop 5 Products based on rating:")
df.sort_values(by='rating', ascending=False).head()
# Out:
# Top 5 Products based on rating:
#        index                                      product  \
# 27515  27516                     EDT Spray - Musk For Men
# 12        13              Face Wash - Oil Control, Active
# 16        17               Smooth Skin Oil - For Dry Skin
# 6133    6134                     Peri Peri Stir-Fry Sauce
# 6178    6179  Disney Frozen Sisters Metal Kids Pencil Box
#
#                    category            sub_category             brand  \
# 27515      Beauty & Hygiene       Fragrances & Deos              Brut
# 12         Beauty & Hygiene               Skin Care               Oxy
# 16         Beauty & Hygiene               Skin Care   Aroma Treasures
# 6133   Gourmet & World Food  Sauces, Spreads & Dips     As Chefs Cook
# 6178   Cleaning & Household              Stationery  Hm International
#
#        sale_price  market_price                    type  rating  \
# 27515       595.0         595.0        Men's Deodorants     5.0
# ...

# %%
top_rated = df.sort_values(by='rating', ascending=False).head(5)
least_rated = df.sort_values(by='rating').head(5)

# %%
# Step 7: Measuring Discount
# Discount = market_price - sale_price
df['discount'] = df['market_price'] - df['sale_price']
print("\nTop 5 Products with Highest Discounts:")
df[['product', 'sale_price', 'market_price', 'discount']].sort_values(by='discount', ascending=False).head()
# Out:
# Top 5 Products with Highest Discounts:
#                                                  product  sale_price  \
# 21930  Premium Cloth Dryer/Drying Stand - Foldable, S...      4649.0
# 23082  Gas Stove-4 Burner Royale Plus Schott Glass, B...      7999.0
# 1056   Gas Stove-3 Burner Royale Plus Schott Glass, B...      6999.0
# 2343   Induction Base Non Stick Cookware Set With Gla...      1399.0
# 8759   Dinner Set - Laser Etched, Premium Stainless S...      2499.0
#
#        market_price  discount
# 21930        8969.0    4320.0
# 23082       12245.0    4246.0
# 1056        10695.0    3696.0
# 2343         4999.0    3600.0
# 8759         5999.0    3500.0

# %%
# Step 8: Missing Values
print("\nMissing Values in Dataset:")
print(df.isnull().sum())
# Out:
# Missing Values in Dataset:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# discount           6
# dtype: int64

# %%
# Step 10: Visualizations
plt.figure(figsize=(10,6))
sns.histplot(df['sale_price'], kde=True)
plt.title('Distribution of Sale Price')
plt.xlabel('Sale Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='category', y='sale_price', data=df)
plt.xticks(rotation=45)
plt.title('Sale Price by Category')
plt.show()

# %%
plt.figure(figsize=(10,6))
top_brands = df['brand'].value_counts().head(10)
sns.barplot(x=top_brands.index, y=top_brands.values)
plt.title('Top 10 Brands')
plt.xticks(rotation=45)
plt.ylabel('Product Count')
plt.show()
